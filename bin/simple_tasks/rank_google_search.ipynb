# %%
import pandas as pd

# %% [markdown]
# # please don't use this search tool for more than 2 times per day.
# ## (Google have a limitation on code accessment, otherwise it will block our future access.)

# %%
## Start from here
## Change keyword inside bracket []
## such as ["Treg scRNAseq"] with the content you need to search

# %%
keyword = ["CRISPR analysis"]

# %%
# !python ./src/sortgs.py --kw $keyword --sortby "cit/year"
df = pd.read_csv("["+ keyword[0].replace(" ", "_") + "].csv", index_col="Rank on Google Scholar")
df.head(25)
# Out:
# Loading next 10 results
# ./src/sortgs.py:253: UserWarning: Year not found for Could not catch title, appending 0
#   warnings.warn("Year not found for {}, appending 0".format(title[-1]))
# Loading next 20 results
# Loading next 30 results
#                                                                    Author  \
# Rank on Google Scholar
# 3                                     Cho, S Kim, Y Kim, J Kweon, HS Kim…
# 15                                     Feng, Y Mao, N Xu, B Zhang, P Wei…
# 4                         Peters, A Colavin, H Shi, TL Czarny, MH Larson…
# 18                      Hsiau, D Conant, N Rossi, T Maures, K Waite, J...
# 14                                     Anderson, M Haeussler, C Watanabe…
# 13                          Wang, M Wang, W Zhang, T Xiao, CH Chen, A Wu…
# 1                                                        Hanna, JG Doench
# 9                                                        Horvath, AC Coût
# ...
